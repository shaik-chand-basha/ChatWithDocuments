# %%
from langchain.agents import create_pandas_dataframe_agent
import os
import pandas as pd
from langchain.chat_models import ChatOpenAI
from langchain.llms import OpenAI
from dotenv import load_dotenv

load_dotenv("./credentials.env")
# Out:
# True

# %% [markdown]
# ### Load LLM

# %%
llm = ChatOpenAI(model = "gpt-3.5-turbo-16k",temperature=0.7)

# %%
# df = pandas.read_csv("../resources/Data Request.csv")

# %% [markdown]
# ### Load sheet

# %%
df = pandas.read_excel("../resources/Data Request.xlsx",sheet_name=0)

# %% [markdown]
# ### create an agent for the DataFrame

# %%
agent = create_pandas_dataframe_agent(df=df,llm=llm,handle_parsing_errors=True)

# %% [markdown]
# ### Questions

# %%
agent.run("what are top 10 cities where Physicians living? plot a pie chart of them")
# Out:
# 'The top 10 cities where physicians are living are Columbia, Falls Church, Albuquerque, Orlando, Honolulu, New York, Baltimore, Houston, Oceanside, and Tampa.'
