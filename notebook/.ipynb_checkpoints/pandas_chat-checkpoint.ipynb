# %%
import pandas as pd
from pandasai import SmartDataframe,SmartDatalake
from pandasai.llm import OpenAI
from dotenv import load_dotenv
import os
load_dotenv("./credentials.env")
# Out:
# True

# %%
data = pd.read_excel("../resources/Data Request.xlsx",sheet_name=None)
if isinstance(data,dict):
    data = [item for key,item in data.items()]
else:
    data = [data]

# %%
llm = OpenAI()

# %%
print(cwd)
# Out:
# b'C:\\Users\\ChandPashaShaik\\Anaconda\\python_code\\Demo-11-10-2023\\notebook'

# %%
df = SmartDatalake(data, config={"llm": llm,"enable_cache":False, "save_charts": True,
    "save_charts_path": "plots/"})

# %%
response = df.chat("describe diagramatically top 10 cities Physicians living?")
print(response)
# Out:
# None
